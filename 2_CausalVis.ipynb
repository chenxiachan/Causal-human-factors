# %%
import networkx as nx
from dagviz import Dagre, Metro

# Create a dictionary to map short variable names to descriptive English labels
node_labels = {
    'light_sat_3': 'Glare on screens Satisfaction',
    'location_type': 'Workspace type',
    'support_sat_3': 'Collaboration support Satisfaction',
    'support_sat_2': 'Creativity support Satisfaction',
    'support_sat_1': 'Focus support Satisfaction',
    'background_gender': 'Gender',
    'furnish_sat_1': 'Furnishings comfort Satisfaction',
    'furnish_sat_2': 'Furnishings adjustability Satisfaction',
    'iaq_sat_1': 'Air quality Satisfaction',
    'acoustic_sat_1': 'Noise level Satisfaction',
    'acoustic_sat_2': 'Acoustic privacy Satisfaction',
    'layout_sat_2': 'Visual privacy Satisfaction',
    'layout_sat_3': 'Ease of interaction Satisfaction',
    'thermal_sat_1': 'Temperature Satisfaction',
    'layout_sat_1': 'Personal space & storage Satisfaction',
    'light_sat_1': 'Electric light amount Satisfaction',
    'light_sat_4': 'Lighting control Satisfaction',
    'thermal_sat_2': 'Temperature control Satisfaction',
    'background_hours': 'Weekly hours spent in workspace',
    'furnish_sat_3': 'Furnishings aesthetics Satisfaction',
    'amenities_sat_5': 'Views from windows throughout office Satisfaction',
    'light_task': 'Allowed to add task lighting',
    'amenities_sat_4': 'Views from windows at workspace Satisfaction',
    'clean_sat_1': 'Office cleanliness Satisfaction',
    'amenities_sat_3': 'Ability to see outdoors from workspace Satisfaction',
    'light_sat_2': 'Daylight amount Satisfaction',
    'background_time': 'Time working at present office',
    'background_work': 'Work type',
    'clean_sat_2': 'Office maintenance Satisfaction'
}
# Define the causal graph
u = nx.DiGraph()
u.add_edge('background_time', 'background_work')
u.add_edge('background_time', 'clean_sat_2')
u.add_edge('background_work', 'clean_sat_2')
u.add_edge('background_hours', 'clean_sat_2')
u.add_edge('background_hours', 'light_sat_2')
u.add_edge('background_hours', 'furnish_sat_3')
u.add_edge('light_sat_2', 'background_time')
u.add_edge('light_sat_2', 'clean_sat_2')
u.add_edge('furnish_sat_3', 'amenities_sat_5')
u.add_edge('amenities_sat_5', 'clean_sat_2')
u.add_edge('amenities_sat_5', 'light_sat_2')
u.add_edge('amenities_sat_5', 'light_task')
u.add_edge('amenities_sat_5', 'amenities_sat_4')
u.add_edge('background_gender', 'background_work')
u.add_edge('background_gender', 'clean_sat_2')
u.add_edge('background_gender', 'thermal_sat_2')
u.add_edge('thermal_sat_2', 'clean_sat_2')
u.add_edge('thermal_sat_2', 'background_hours')
u.add_edge('thermal_sat_2', 'clean_sat_1')
u.add_edge('clean_sat_1', 'clean_sat_2')
u.add_edge('clean_sat_1', 'light_sat_2')
u.add_edge('iaq_sat_1', 'background_work')
u.add_edge('iaq_sat_1', 'acoustic_sat_1')
u.add_edge('iaq_sat_1', 'layout_sat_3')
u.add_edge('acoustic_sat_1', 'acoustic_sat_2')
u.add_edge('layout_sat_3', 'furnish_sat_3')
u.add_edge('layout_sat_3', 'thermal_sat_1')
u.add_edge('layout_sat_3', 'light_sat_4')
u.add_edge('layout_sat_3', 'layout_sat_1')
u.add_edge('acoustic_sat_2', 'clean_sat_2')
u.add_edge('acoustic_sat_2', 'layout_sat_3')
u.add_edge('acoustic_sat_2', 'light_sat_1')
u.add_edge('acoustic_sat_2', 'layout_sat_2')
u.add_edge('acoustic_sat_2', 'amenities_sat_4')
u.add_edge('thermal_sat_1', 'light_sat_2')
u.add_edge('thermal_sat_1', 'thermal_sat_2')
u.add_edge('thermal_sat_1', 'light_sat_1')
u.add_edge('light_sat_4', 'clean_sat_2')
u.add_edge('light_sat_4', 'thermal_sat_2')
u.add_edge('light_sat_4', 'light_task')
u.add_edge('light_sat_1', 'clean_sat_2')
u.add_edge('light_sat_1', 'light_sat_2')
u.add_edge('light_sat_1', 'light_sat_4')
u.add_edge('light_task', 'clean_sat_2')
u.add_edge('light_task', 'light_sat_2')
u.add_edge('light_sat_3', 'light_sat_2')
u.add_edge('light_sat_3', 'acoustic_sat_1')
u.add_edge('light_sat_3', 'light_sat_1')
u.add_edge('light_sat_3', 'amenities_sat_3')
u.add_edge('light_sat_3', 'support_sat_2')
u.add_edge('amenities_sat_3', 'light_sat_2')
u.add_edge('support_sat_2', 'clean_sat_2')
u.add_edge('support_sat_2', 'furnish_sat_3')
u.add_edge('support_sat_2', 'light_sat_4')
u.add_edge('support_sat_2', 'amenities_sat_3')
u.add_edge('support_sat_2', 'support_sat_1')
u.add_edge('support_sat_1', 'background_work')
u.add_edge('support_sat_1', 'furnish_sat_3')
u.add_edge('support_sat_1', 'background_gender')
u.add_edge('support_sat_1', 'acoustic_sat_1')
u.add_edge('support_sat_1', 'furnish_sat_1')
u.add_edge('layout_sat_2', 'clean_sat_2')
u.add_edge('layout_sat_2', 'layout_sat_3')
u.add_edge('amenities_sat_4', 'clean_sat_1')
u.add_edge('amenities_sat_4', 'amenities_sat_3')
u.add_edge('furnish_sat_1', 'furnish_sat_2')
u.add_edge('furnish_sat_2', 'furnish_sat_3')
u.add_edge('furnish_sat_2', 'iaq_sat_1')
u.add_edge('furnish_sat_2', 'layout_sat_2')
u.add_edge('location_type', 'furnish_sat_3')
u.add_edge('location_type', 'amenities_sat_5')
u.add_edge('location_type', 'layout_sat_2')
u.add_edge('support_sat_3', 'furnish_sat_3')
u.add_edge('support_sat_3', 'iaq_sat_1')
u.add_edge('support_sat_3', 'layout_sat_3')
u.add_edge('support_sat_3', 'amenities_sat_3')
u.add_edge('support_sat_3', 'support_sat_2')

# Set the labels on the nodes using a dictionary
nx.set_node_attributes(u, node_labels, 'label')

# Draw the Metro diagram with the descriptive labels
Metro(u)
# Out:
# <svg baseProfile="full" height="100%" version="1.1" viewBox="25.0,5.0,725.0,580.0" width="100%" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs /><g><line stroke="lightgrey" stroke-dasharray="2" x1="370.0" x2="369.0" y1="15.0" y2="15.0" /><line stroke="lightgrey" stroke-dasharray="2" x1="350.0" x2="369.0" y1="35.0" y2="35.0" /><line stroke="lightgrey" stroke-dasharray="2" x1="330.0" x2="369.0" y1="55.0" y2="55.0" /><line stroke="lightgrey" stroke-dasharray="2" x1="310.0" x2="369.0" y1="75.0" y2="75.0" /><line stroke="lightgrey" stroke-dasharray="2" x1="290.0" x2="369.0" y1="95.0" y2="95.0" /><line stroke="lightgrey" stroke-dasharray="2" x1="270.0" x2="369.0" y1="115.0" y2="115.0" /><line stroke="lightgrey" stroke-dasharray="2" x1="250.0" x2="369.0" y1="135.0" y2="135.0" /><line stroke="lightgrey" stroke-dasharray="2" x1="250.0" x2="369.0" y1="155.0" y2="155.0" /><line stroke="lightgrey" stroke-dasharray=
# ...

# %%
import networkx as nx
import pygraphviz as pgv

u = nx.DiGraph()
edges = [
    ('background_time', 'background_work'), ('background_time', 'clean_sat_2'),
    ('background_work', 'clean_sat_2'), ('background_hours', 'clean_sat_2'),
    ('background_hours', 'light_sat_2'), ('background_hours', 'furnish_sat_3'),
    ('light_sat_2', 'background_time'), ('light_sat_2', 'clean_sat_2'),
    ('furnish_sat_3', 'amenities_sat_5'), ('amenities_sat_5', 'clean_sat_2'),
    ('amenities_sat_5', 'light_sat_2'), ('amenities_sat_5', 'light_task'),
    ('amenities_sat_5', 'amenities_sat_4'), ('background_gender', 'background_work'),
    ('background_gender', 'clean_sat_2'), ('background_gender', 'thermal_sat_2'),
    ('thermal_sat_2', 'clean_sat_2'), ('thermal_sat_2', 'background_hours'),
    ('thermal_sat_2', 'clean_sat_1'), ('clean_sat_1', 'clean_sat_2'),
    ('clean_sat_1', 'light_sat_2'), ('iaq_sat_1', 'background_work'),
    ('iaq_sat_1', 'acoustic_sat_1'), ('iaq_sat_1', 'layout_sat_3'),
    ('acoustic_sat_1', 'acoustic_sat_2'), ('layout_sat_3', 'furnish_sat_3'),
    ('layout_sat_3', 'thermal_sat_1'), ('layout_sat_3', 'light_sat_4'),
    ('layout_sat_3', 'layout_sat_1'), ('acoustic_sat_2', 'clean_sat_2'),
    ('acoustic_sat_2', 'layout_sat_3'), ('acoustic_sat_2', 'light_sat_1'),
    ('acoustic_sat_2', 'layout_sat_2'), ('acoustic_sat_2', 'amenities_sat_4'),
    ('thermal_sat_1', 'light_sat_2'), ('thermal_sat_1', 'thermal_sat_2'),
    ('thermal_sat_1', 'light_sat_1'), ('light_sat_4', 'clean_sat_2'),
    ('light_sat_4', 'thermal_sat_2'), ('light_sat_4', 'light_task'),
    ('light_sat_1', 'clean_sat_2'), ('light_sat_1', 'light_sat_2'),
    ('light_sat_1', 'light_sat_4'), ('light_task', 'clean_sat_2'),
    ('light_task', 'light_sat_2'), ('light_sat_3', 'light_sat_2'),
    ('light_sat_3', 'acoustic_sat_1'), ('light_sat_3', 'light_sat_1'),
    ('light_sat_3', 'amenities_sat_3'), ('light_sat_3', 'support_sat_2'),
    ('amenities_sat_3', 'light_sat_2'), ('support_sat_2', 'clean_sat_2'),
    ('support_sat_2', 'furnish_sat_3'), ('support_sat_2', 'light_sat_4'),
    ('support_sat_2', 'amenities_sat_3'), ('support_sat_2', 'support_sat_1'),
    ('support_sat_1', 'background_work'), ('support_sat_1', 'furnish_sat_3'),
    ('support_sat_1', 'background_gender'), ('support_sat_1', 'acoustic_sat_1'),
    ('support_sat_1', 'furnish_sat_1'), ('layout_sat_2', 'clean_sat_2'),
    ('layout_sat_2', 'layout_sat_3'), ('amenities_sat_4', 'clean_sat_1'),
    ('amenities_sat_4', 'amenities_sat_3'), ('furnish_sat_1', 'furnish_sat_2'),
    ('furnish_sat_2', 'furnish_sat_3'), ('furnish_sat_2', 'iaq_sat_1'),
    ('furnish_sat_2', 'layout_sat_2'), ('location_type', 'furnish_sat_3'),
    ('location_type', 'amenities_sat_5'), ('location_type', 'layout_sat_2'),
    ('support_sat_3', 'furnish_sat_3'), ('support_sat_3', 'iaq_sat_1'),
    ('support_sat_3', 'layout_sat_3'), ('support_sat_3', 'amenities_sat_3'),
    ('support_sat_3', 'support_sat_2')
]
u.add_edges_from(edges)

node_labels = {
    'background_gender': 'Gender',
    'background_hours': 'Weekly Hours in Workspace',
    'background_time': 'Time at Present Office',
    'background_work': 'Work Type',
    'location_type': 'Workspace Type',
    'light_task': 'Allowed Task Lighting',
    'light_sat_1': 'Electric Light Sat.',
    'light_sat_2': 'Daylight Amount Sat.',
    'light_sat_3': 'Screen Glare Sat.',
    'light_sat_4': 'Lighting Control Sat.',
    'thermal_sat_1': 'Temperature Sat.',
    'thermal_sat_2': 'Temp. Control Sat.',
    'iaq_sat_1': 'Air Quality Sat.',
    'acoustic_sat_1': 'Noise Level Sat.',
    'acoustic_sat_2': 'Acoustic Privacy Sat.',
    'clean_sat_1': 'Office Cleanliness Sat.',
    'clean_sat_2': 'Office Maintenance Sat.',
    'furnish_sat_1': 'Furnishings Comfort Sat.',
    'furnish_sat_2': 'Furnishings Adjustability Sat.',
    'furnish_sat_3': 'Furnishings Aesthetics Sat.',
    'layout_sat_1': 'Personal Space & Storage Sat.',
    'layout_sat_2': 'Visual Privacy Sat.',
    'layout_sat_3': 'Ease of Interaction Sat.',
    'amenities_sat_3': 'Outdoor Visibility Sat.',
    'amenities_sat_4': 'Views at Workspace Sat.',
    'amenities_sat_5': 'Views throughout Office Sat.',
    'support_sat_1': 'Focus Support Sat.',
    'support_sat_2': 'Creativity Support Sat.',
    'support_sat_3': 'Collaboration Support Sat.'
}

A = nx.nx_agraph.to_agraph(u)

for node in A.nodes():
    node.attr['label'] = node_labels.get(node, node)


A.graph_attr.update(fontsize=20) 

A.node_attr.update(shape='box', style='rounded', fontsize=20) 
A.graph_attr.update(
    ranksep='0.35',    
    nodesep='0.2',    
)
A.edge_attr.update()

A.graph_attr.update(sep='+20', overlap='false')

A.layout(prog='dot')
A.draw("causal_diagram_labeled.png")
